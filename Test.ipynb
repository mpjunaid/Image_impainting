# %%
import torch
from torchvision import datasets, transforms
import numpy as np

# %%
data_dir = './img_align_celeba'

transform = transforms.Compose([

transforms.ToTensor(),
transforms.RandomErasing()

])

dataset = datasets.ImageFolder(data_dir, transform=transform)

dataloader = torch.utils.data.DataLoader(dataset, batch_size=32, shuffle=True)

images, labels = next(iter(dataloader))

# helper.imshow(images[0], normalize=False)

# %%
images.shape
# Out:
# torch.Size([32, 3, 218, 178])

# %%
images[0][0][0]
# Out:
# tensor([0.9020, 0.9020, 0.9020, 0.9020, 0.9020, 0.9020, 0.9020, 0.9020, 0.9020,
#         0.9020, 0.9020, 0.9020, 0.9020, 0.9020, 0.9020, 0.9020, 0.9020, 0.9020,
#         0.9020, 0.9020, 0.9020, 0.9020, 0.9020, 0.9020, 0.9020, 0.9020, 0.9020,
#         0.9020, 0.9020, 0.9020, 0.9020, 0.9020, 0.9020, 0.9020, 0.9020, 0.9020,
#         0.9020, 0.9020, 0.9020, 0.9020, 0.9020, 0.9020, 0.9020, 0.9020, 0.9020,
#         0.9020, 0.9020, 0.9020, 0.9020, 0.9020, 0.9020, 0.9020, 0.9020, 0.9020,
#         0.9020, 0.9020, 0.9020, 0.9020, 0.9020, 0.9020, 0.9020, 0.9020, 0.9020,
#         0.9020, 0.9020, 0.9020, 0.9020, 0.8980, 0.8980, 0.8941, 0.8941, 0.8941,
#         0.8980, 0.9020, 0.9020, 0.9059, 0.9059, 0.9020, 0.9020, 0.8980, 0.9020,
#         0.9020, 0.9020, 0.9020, 0.9020, 0.9020, 0.9020, 0.9020, 0.9020, 0.9020,
#         0.9020, 0.9020, 0.9020, 0.9020, 0.9020, 0.9020, 0.9020, 0.9020, 0.9020,
#         0.9020, 0.9020, 0.9020, 0.9020, 0.9020, 0.9020, 0.9020, 0.9020, 0.9020,
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(  images[8].permute(1, 2, 0)  )

# %%
plt.imshow(  images[10].permute(1, 2, 0)  )

# %%
import skimage

# %%
mask = np.ones(shape=images[0].shape[0:2], dtype="bool")

# %%
mask
# Out:
# array([[ True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
# ...

# %%
rr, cc = skimage.draw.rectangle(start=(100, 44), end=(140, 120))
mask[rr, cc] = False
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-2153d00d9b59> in <module>
# ----> 1 rr, cc = skimage.draw.rectangle(start=(100, 44), end=(140, 120))
#       2 mask[rr, cc] = False
#
# AttributeError: module 'skimage' has no attribute 'draw'

# %%
from PIL import Image, ImageDraw
# im = Image.new('RGBA', (400, 400), (0, 255, 0, 0)) 
draw = ImageDraw.Draw(images[0]) 
draw.line((100,100, 150,100), fill=128)
im.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\conda\envs\pytorch\lib\site-packages\PIL\ImageDraw.py in Draw(im, mode)
#     771     try:
# --> 772         return im.getdraw(mode)
#     773     except AttributeError:
#
# AttributeError: 'Tensor' object has no attribute 'getdraw'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-49-7a2903c4ca40> in <module>
#       1 from PIL import Image, ImageDraw
#       2 # im = Image.new('RGBA', (400, 400), (0, 255, 0, 0))
# ----> 3 draw = ImageDraw.Draw(images[0])
#       4 draw.line((100,100, 150,100), fill=128)
#       5 im.show()
#
# C:\conda\envs\pytorch\lib\site-packages\PIL\ImageDraw.py in Draw(im, mode)
#     772         return im.getdraw(mode)
#     773     except AttributeError:
# ...

# %%
image = cv2.imread(path) 

start_point = (5, 5) 
end_point = (220, 220) 
  
# Blue color in BGR 
color = (255, 0, 0) 
  
# Line thickness of 2 px 
thickness = 2
  
# Using cv2.rectangle() method 
# Draw a rectangle with blue line borders of thickness of 2 px 
image = cv2.rectangle(image, start_point, end_point, color, thickness)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-53ee17c76512> in <module>
# ----> 1 image = cv2.imread(path)
#       2
#       3 start_point = (5, 5)
#       4 end_point = (220, 220)
#       5
#
# NameError: name 'path' is not defined

# %%
# !pip install cv2
# Out:
# ERROR: Could not find a version that satisfies the requirement cv2
# ERROR: No matching distribution found for cv2
